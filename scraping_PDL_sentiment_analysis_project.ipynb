# %% [markdown]
# Install library untuk scraping

# %%
# !pip install google-play-scraper pandas
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %% [markdown]
# import library

# %%
from google_play_scraper import app, Sort, reviews_all
import pandas as pd
from datetime import datetime
import time

# %% [markdown]
# kode scraping

# %%
# Mengambil semua ulasan dari aplikasi
scrapreview = reviews_all(
    'com.gojek.app',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=15000
)

# %%
app_reviews_df = pd.DataFrame(scrapreview)

# %%
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  5e85ee5b-2e4e-4d11-b2fd-e13e2b76f58d  Pengguna Google
# 1  87c955c3-b60b-4364-8d07-f7ab95e7f081  Pengguna Google
# 2  5684ecb2-9680-4f86-ac45-62e34cecb98c  Pengguna Google
# 3  5423592c-020f-4938-9f04-73217847417c  Pengguna Google
# 4  37a64afe-3f0e-466a-9e8e-3228391f58b8  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasinya sudah bagus meski terkadang ada bu...      4              1
# 1  hallo admin dari aplikasi kocak, bisa bisanya ...      1              5
# 2  Saran kalau semisal kita dapat driver posisi a...      1            100
# 3  Fitur gofood nya kyk sampah, dikasih opsi peng...      1             62
# 4  aplikasinya sudah bagus,dan memudahkan juga bu...      4              1
#
#   reviewCreatedVersion                  at  \
# 0               5.36.2 2025-10-27 09:41:09
# 1               5.35.1 2025-10-27 11:04:31
# 2               5.34.1 2025-10-04 10:27:01
# 3               5.32.1 2025-10-18 07:16:22
# 4               5.36.2 2025-10-26 23:07:46
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3  Hai Kak Rizi, mohon maaf atas ketidaknyamanann... 2025-10-18 09:56:11
# 4                                               None                 NaT
#
#   appVersion
# 0     5.36.2
# 1     5.35.1
# 2     5.34.1
# 3     5.32.1
# 4     5.36.2

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144000 entries, 0 to 143999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              144000 non-null  object
#  1   userName              144000 non-null  object
#  2   userImage             144000 non-null  object
#  3   content               144000 non-null  object
#  4   score                 144000 non-null  int64
#  5   thumbsUpCount         144000 non-null  int64
#  6   reviewCreatedVersion  113436 non-null  object
#  7   at                    144000 non-null  datetime64[ns]
#  8   replyContent          46354 non-null   object
#  9   repliedAt             46354 non-null   datetime64[ns]
#  10  appVersion            113436 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 12.1+ MB

# %% [markdown]
# Membersihkan dataset

# %%
# Membuat DataFrame baru (clean_df) dengan menghapus baris yang memiliki nilai yang hilang (NaN) dari app_reviews_df
clean_df = app_reviews_df.dropna()

# %%
# Menghapus baris duplikat dari DataFrame clean_df
clean_df = clean_df.drop_duplicates()

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35782 entries, 3 to 143999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              35782 non-null  object
#  1   userName              35782 non-null  object
#  2   userImage             35782 non-null  object
#  3   content               35782 non-null  object
#  4   score                 35782 non-null  int64
#  5   thumbsUpCount         35782 non-null  int64
#  6   reviewCreatedVersion  35782 non-null  object
#  7   at                    35782 non-null  datetime64[ns]
#  8   replyContent          35782 non-null  object
#  9   repliedAt             35782 non-null  datetime64[ns]
#  10  appVersion            35782 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 3.3+ MB

# %% [markdown]
# Menyimpan dataset ke csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
save_path = '/content/drive/MyDrive/Colab Notebooks/Sentiment_analysis_project/dataset/app_reviews.csv'
clean_df.to_csv(save_path, index=False)
